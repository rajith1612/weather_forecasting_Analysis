# %%
import pandas as pd

# load dataset (use your correct path)
df = pd.read_csv(r"/Users/lakshmanrajith/Desktop/weather_forcasting/Data/raw/GlobalWeatherRepository.csv")

print("Loaded:", df.shape)
# Out:
# Loaded: (123746, 41)

# %% [markdown]
# Check missing values

# %%
df.isnull().sum().sort_values(ascending=False).head(15)
# Out:
# country                         0
# feels_like_fahrenheit           0
# visibility_miles                0
# uv_index                        0
# gust_mph                        0
# gust_kph                        0
# air_quality_Carbon_Monoxide     0
# air_quality_Ozone               0
# air_quality_Nitrogen_dioxide    0
# air_quality_Sulphur_dioxide     0
# air_quality_PM2.5               0
# air_quality_PM10                0
# air_quality_us-epa-index        0
# air_quality_gb-defra-index      0
# sunrise                         0
# dtype: int64

# %% [markdown]
# Then handle missing values

# %%
# fill numeric columns
numeric_cols = df.select_dtypes(include='number').columns
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

# fill categorical columns
categorical_cols = df.select_dtypes(include='object').columns
df[categorical_cols] = df[categorical_cols].fillna("Unknown")

# %% [markdown]
# Remove duplicates

# %%
df = df.drop_duplicates()
print("Shape after duplicates removed:", df.shape)
# Out:
# Shape after duplicates removed: (123746, 41)

# %% [markdown]
# Remove unrealistic temperature values

# %%
df = df[(df['temperature_celsius'] > -50) & (df['temperature_celsius'] < 60)]
print("Shape after temperature filter:", df.shape)
# Out:
# Shape after temperature filter: (123746, 41)

# %% [markdown]
# Save cleaned data

# %%
import os
print(os.getcwd())
# Out:
# /Users/lakshmanrajith/Desktop/weather_forcasting/notebooks

# %%
import os
print(os.listdir())
# Out:
# ['main.ipynb', 'weather_clean.parquet', '.ipynb_checkpoints', 'data']

# %%
import os
os.makedirs("data/processed", exist_ok=True)

df.to_parquet("Data/processed/weather_clean.parquet", index=False)

# %%
import pandas as pd

df = pd.read_parquet("/Users/lakshmanrajith/Desktop/weather_forcasting/Data/processed/weather_clean.parquet")

df.to_csv("/Users/lakshmanrajith/Desktop/weather_forcasting/Data/processed/weather_clean.csv", index=False)

print("CSV saved successfully")
# Out:
# CSV saved successfully
